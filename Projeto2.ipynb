# %% [markdown]
# <a href="https://colab.research.google.com/github/roberto-adrego/Pos_dsa/blob/main/Projeto2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <!-- Projeto Desenvolvido na Data Science Academy - www.datascienceacademy.com.br -->
# # <font color='blue'>Data Science Academy</font>
# ## <font color='blue'>IA Generativa e LLMs Para Processamento de Linguagem Natural</font>
# ## <font color='blue'>Projeto 2</font>
# ## <font color='blue'>Fine-Tuning Eficiente de LLMs com LoRA Para Análise de Sentimentos em Texto</font>

# %% [markdown]
# ## Instalando e Carregando Pacotes

# %%
# !pip install -q -U watermark

# %% [markdown]
# A descrição de cada um dos pacotes abaixo está disponível no Capítulo 7 do Curso.
#
# https://www.datascienceacademy.com.br/course/ia-generativa-e-llms-para-processamento-de-linguagem-natural

# %%
# !pip install -q accelerate==1.9.0 peft==0.16.0 bitsandbytes==0.46.1 transformers==4.54.0

# %%
# !pip install -q trl==0.20.0 gradio==5.38.2 protobuf scipy==1.16.0

# %%
# !pip install -q sentencepiece==0.2.0 tokenizers==0.21.2 datasets==4.0.0

# %%
# %reload_ext watermark
# %watermark -a "Data Science Academy"
# Out:
# Author: Data Science Academy

# %%
# Imports
import os
import torch
import datasets
import pandas as pd
from datasets import load_dataset
from transformers import (AutoModelForCausalLM,
                          AutoTokenizer,
                          BitsAndBytesConfig,
                          HfArgumentParser,
                          TrainingArguments,
                          pipeline,
                          logging)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer, SFTConfig
import warnings
warnings.filterwarnings('ignore')

# %%
# Define o nível de log para CRITICAL
logging.set_verbosity(logging.CRITICAL)

# %%
# Verifica o modelo da GPU
if torch.cuda.is_available():
    print('Número de GPUs:', torch.cuda.device_count())
    print('Modelo GPU:', torch.cuda.get_device_name(0))
    print('Total Memória [GB] da GPU:',torch.cuda.get_device_properties(0).total_memory / 1e9)
# Out:
# Número de GPUs: 1
# Modelo GPU: NVIDIA A100-SXM4-40GB
# Total Memória [GB] da GPU: 42.474471424

# %%
# Reset da memória da GPU
from numba import cuda
device = cuda.get_current_device()
device.reset()

# %%
# Define o nome do dataset
nome_dataset = "dataset.csv"

# %%
# Carrega os dados
dataset_carregado = load_dataset('csv', data_files = nome_dataset, delimiter = ',')
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
# Dados Carregados no Formato de Dicionário
dataset_carregado
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['train'],
#         num_rows: 17057
#     })
# })

# %% [markdown]
# https://huggingface.co/NousResearch/Llama-2-7b-chat-hf

# %%
# Nome do repositório do LLM pré-treinado
repositorio_hf = "NousResearch/Llama-2-7b-chat-hf"

# %%
# Nome do novo modelo
modelo_dsa = "novo_modelo_dsa"

# %% [markdown]
# ## Definindo os Parâmetros de Configuração

# %%
# Parâmetros LoRA
lora_r = 32
lora_alpha = 16
lora_dropout = 0.1

# %% [markdown]
# Os parâmetros acima são do LoRa (Low-Rank Adaptation), a parte base do QLoRA (Quantized Low-Rank Adaptation), uma técnica utilizada para adaptar modelos de linguagem de forma eficiente. Acima dos parâmetros LoRa colocamos os parâmetros de quantização, definindo assim o QLoRa.
#
# Vamos descrever cada um dos parâmetros:
#
# **lora_r**: Este parâmetro representa o "rank" na adaptação de Low-Rank (LoRA). Um valor de 32 significa que a matriz de pesos do modelo original será aproximada por duas matrizes menores cujo produto possui um rank máximo de 32. Essencialmente, isso reduz a complexidade computacional e o número de parâmetros a serem treinados durante a adaptação, mantendo a eficácia do modelo.
#
# **lora_alpha**: Este é um fator de escala que é aplicado às atualizações de peso do LoRA durante o treinamento. Um valor de 16 indica que as atualizações de pesos serão escaladas por este fator. Esse parâmetro é importante porque permite um controle fino sobre a magnitude das atualizações dos pesos, o que pode afetar a rapidez e a eficácia da adaptação do modelo.
#
# **lora_dropout**: Este parâmetro representa a taxa de "dropout" aplicada durante a adaptação do modelo. O valor 0.1 significa que 10% das unidades serão aleatoriamente descartadas (ou "desligadas") durante o treinamento. O dropout é uma técnica comum para evitar o overfitting em redes neurais, garantindo que o modelo não se torne excessivamente dependente de qualquer parte específica dos dados de treinamento.

# %%
# Parâmetros bitsandbytes (QLoRa)
use_4bit = True
bnb_4bit_compute_dtype = "float16"
bnb_4bit_quant_type = "nf4"
use_nested_quant = False

# %% [markdown]
# Os parâmetros acima são para a biblioteca bitsandbytes, uma ferramenta para otimização de treinamento de modelos de aprendizado de máquina, em particular para reduzir o uso de memória e acelerar o treinamento. Aqui está a explicação de cada parâmetro:
#
# **use_4bit**: Este parâmetro indica se a quantização de 4 bits deve ser usada ou não. Ao definir True, isso significa que o modelo irá utilizar uma representação de 4 bits para os pesos durante o treinamento. Isso reduz significativamente a quantidade de memória necessária, permitindo treinar modelos maiores ou reduzir os requisitos de hardware.
#
# **bnb_4bit_compute_dtype**: Este é o tipo de dado usado para cálculos durante o treinamento quando a quantização de 4 bits está ativa. O valor float16 significa que os cálculos serão feitos usando números de ponto flutuante de 16 bits. Isso é geralmente usado para equilibrar a eficiência computacional e a precisão numérica.
#
# **bnb_4bit_quant_type**: Especifica o tipo de quantização a ser usado. O valor nf4 é um tipo específico de quantização desenvolvido pela bitsandbytes, otimizado para eficiência e eficácia em treinamento de modelos de aprendizado profundo. Este tipo de quantização é projetado para manter a precisão do modelo enquanto reduz os requisitos de memória.
#
# **use_nested_quant**: Indica se uma técnica de quantização aninhada será usada. False significa que essa técnica não será empregada. A quantização aninhada pode ser usada para reduzir ainda mais o uso de memória, aplicando diferentes níveis de quantização a diferentes partes do modelo, mas pode ser mais complexa de implementar e gerenciar.
#
# Esses parâmetros são usados para configurar como o modelo de aprendizado profundo irá lidar com a representação e cálculo dos pesos durante o treinamento, visando otimizar o uso de memória e acelerar o processo de treinamento.

# %%
# Parâmetros do ajuste fino
output_dir = "saida"
num_train_epochs = 1
fp16 = True
bf16 = False
per_device_train_batch_size = 4
per_device_eval_batch_size = 4
gradient_accumulation_steps = 1
gradient_checkpointing = True
max_grad_norm = 0.3
learning_rate = 2e-4
weight_decay = 0.001
optim = "paged_adamw_32bit"
lr_scheduler_type = "cosine"
max_steps = -1
warmup_ratio = 0.03

# %% [markdown]
# Os parâmetros acima são usados para configurar o processo de ajuste fino (fine-tuning) de modelos de aprendizado de máquina, especialmente modelos de linguagem natural. Vamos descrever cada um deles:
#
# **output_dir**: Especifica o diretório onde os resultados do treinamento serão salvos.
#
# **num_train_epochs**: O número de épocas de treinamento. O valor 1 significa que o modelo passará uma vez por todo o conjunto de dados de treinamento.
#
# **fp16**: Indica se deve ser usado o treinamento com precisão mista de ponto flutuante de 16 bits (FP16). O valor True significa que sim, o que pode acelerar o treinamento e reduzir o uso de memória, mantendo uma precisão aceitável.
#
# **bf16**: Semelhante ao fp16, mas para o formato bfloat16. False significa que não será utilizado. O formato bfloat16 é outra forma de reduzir o uso de memória e acelerar o treinamento, com impactos ligeiramente diferentes na precisão. Podemos usar fp16 ou bf16, mas não podemos usar ambos simultaneamente.
#
# **per_device_train_batch_size**: Tamanho do lote de treinamento por dispositivo. O valor 4 indica que cada dispositivo de treinamento (como uma GPU) processará 4 exemplos por lote.
#
# **per_device_eval_batch_size**: Tamanho do lote de avaliação por dispositivo, também definido como 4.
#
# **gradient_accumulation_steps**: Número de passos para acumulação de gradientes antes de realizar uma atualização de parâmetros. O valor 1 significa que não há acumulação (cada passo resulta em uma atualização).
#
# **gradient_checkpointing**: Habilita o checkpointing de gradientes, que é uma técnica para reduzir o uso de memória ao custo de um tempo de treinamento ligeiramente maior. True indica que está habilitado.
#
# **max_grad_norm**: Norma máxima para o corte de gradientes. O valor 0.3 é um valor que ajuda a evitar o problema de explosão de gradientes em treinamentos.
#
# **learning_rate**: Taxa de aprendizado inicial. O valor 2e-4 é um valor comum para ajuste fino, proporcionando um equilíbrio entre a velocidade de aprendizado e a estabilidade.
#
# **weight_decay**: Taxa de decaimento de peso, usada para regularização. O valor 0.001 é um valor que ajuda a prevenir o overfitting.
#
# **optim**: O otimizador usado. "paged_adamw_32bit" é uma variante do AdamW otimizado para eficiência em termos de memória.
#
# **lr_scheduler_type**: Tipo de agendador de taxa de aprendizado. O valor "cosine" indica o uso do agendador cosseno, que ajusta a taxa de aprendizado seguindo uma curva cosseno.
#
# **max_steps**: Número máximo de passos de treinamento. O valor -1 significa que o treinamento continuará até que o número de épocas seja alcançado.
#
# **warmup_ratio**: Proporção do número total de passos de treinamento usados para o aquecimento linear da taxa de aprendizado. O valor 0.03 significa que 3% do treinamento inicial será usado para aumentar gradualmente a taxa de aprendizado.
#
# Esses parâmetros são essenciais para configurar de maneira eficiente o processo de ajuste fino, impactando diretamente na qualidade do modelo treinado, no tempo de treinamento e no uso de recursos computacionais.

# %%
# Agrupando sequências em lotes de mesmo comprimento
group_by_length = True
save_steps = 0
logging_steps = 400

# %% [markdown]
# <!-- Projeto Desenvolvido na Data Science Academy - www.datascienceacademy.com.br -->
# Os parâmetros acima são usados para configurar certos aspectos do processo de treinamento de modelos de aprendizado de máquina, especialmente modelos de linguagem. Eles estão relacionados a como as sequências são agrupadas em lotes e como o progresso do treinamento é registrado e salvo. Vamos detalhar cada um:
#
# **group_by_length**: Este parâmetro indica se as sequências devem ser agrupadas por comprimento ao formar lotes de treinamento. Quando True, isso significa que o treinamento agrupará sequências de comprimentos semelhantes juntas em um lote. Esta é uma prática eficiente porque reduz a quantidade de preenchimento (padding) necessário. O preenchimento é usado para garantir que todas as sequências em um lote tenham o mesmo comprimento, mas pode ser um desperdício de recursos computacionais. Agrupar sequências de comprimentos semelhantes minimiza esse desperdício.
#
# **save_steps**: Especifica a frequência com que o modelo treinado deve ser salvo. Um valor de 0 indica que o modelo não será salvo automaticamente com base em um número de passos. Em vez disso, o modelo pode ser salvo no final de cada época de treinamento ou manualmente.
#
# **logging_steps**: Define a frequência com que as informações de log devem ser registradas. O valor 400 significa que o processo de treinamento registrará informações como a perda de treinamento (loss), métricas de avaliação, entre outros, a cada 400 passos de treinamento. Isso é útil para monitorar o progresso do treinamento e para o ajuste fino dos hiperparâmetros.

# %%
# Precisão dos dados para treinamento
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

# %% [markdown]
# O código acima está relacionado à configuração do tipo de dado (dtype) para computação durante o treinamento de modelos de rede neural usando a biblioteca PyTorch. Vamos analisar cada parte do código:
#
# **torch**: É uma referência à biblioteca PyTorch, uma biblioteca para aprendizado de máquina e redes neurais.
#
# **bnb_4bit_compute_dtype**: Esta é uma variável que armazena uma string representando o tipo de dado desejado para computação. O parâmetro bnb_4bit_compute_dtype foi definido como "float16", indicando que a computação deve ser realizada usando números de ponto flutuante de 16 bits.
#
# **getattr**: É uma função Python built-in usada para obter um atributo de um objeto. Neste caso, ela está sendo usada para obter um atributo da biblioteca PyTorch com base no valor da string armazenada em bnb_4bit_compute_dtype.
#
# O que acontece aqui é que getattr(torch, bnb_4bit_compute_dtype) recupera o tipo de dados de ponto flutuante de 16 bits (torch.float16) da biblioteca PyTorch, com base no valor de bnb_4bit_compute_dtype. Em seguida, esse tipo de dados é atribuído à variável compute_dtype.
#
# O uso de compute_dtype no treinamento de modelos de rede neural tem implicações importantes:
#
# **Eficiência de Memória**: Usar float16 ao invés de tipos de dados mais comuns como float32 pode reduzir significativamente o uso de memória, permitindo o treinamento de modelos maiores ou a execução de mais processos em paralelo.
#
# **Velocidade de Computação**: Muitas GPUs modernas têm otimizações para cálculos float16, o que pode acelerar o treinamento.
#
# **Precisão**: Embora float16 possa ser menos preciso do que float32, muitas vezes é suficientemente preciso para tarefas de treinamento de modelos de rede neural.

# %%
# Definindo os parâmetros da quantização
bnb_config = BitsAndBytesConfig(load_in_4bit = use_4bit,
                                bnb_4bit_quant_type = bnb_4bit_quant_type,
                                bnb_4bit_compute_dtype = compute_dtype,
                                bnb_4bit_use_double_quant = use_nested_quant)

# %%
# Carregando o modelo base pré-treinado
modelo = AutoModelForCausalLM.from_pretrained(repositorio_hf,
                                              quantization_config = bnb_config,
                                              device_map = "auto")
# Out:
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]

# %%
# Não usaremos o cache
modelo.config.use_cache = False
modelo.config.pretraining_tp = 1

# %%
# Carregando o tokenizador do modelo base
tokenizador = AutoTokenizer.from_pretrained(repositorio_hf, trust_remote_code = True)
tokenizador.pad_token = tokenizador.eos_token
tokenizador.padding_side = "right"
# Out:
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %%
# Carregando a configuração LoRA
peft_config = LoraConfig(lora_alpha = lora_alpha,
                         lora_dropout = lora_dropout,
                         r = lora_r,
                         bias = "none",
                         task_type = "CAUSAL_LM")

# %% [markdown]
# https://github.com/huggingface/peft/blob/main/src/peft/tuners/lora/config.py

# %%
# Definindo os parâmetros de treino
training_arguments = TrainingArguments(output_dir = output_dir,
                                       num_train_epochs = num_train_epochs,
                                       per_device_train_batch_size = per_device_train_batch_size,
                                       gradient_accumulation_steps = gradient_accumulation_steps,
                                       optim = optim,
                                       save_steps = save_steps,
                                       logging_steps = logging_steps,
                                       learning_rate = learning_rate,
                                       weight_decay = weight_decay,
                                       fp16 = fp16,
                                       bf16 = bf16,
                                       max_grad_norm = max_grad_norm,
                                       max_steps = max_steps,
                                       warmup_ratio = warmup_ratio,
                                       group_by_length = group_by_length,
                                       lr_scheduler_type = lr_scheduler_type)

# %% [markdown]
# Veja a descrição de Supervised Fine-Tuning e RLHF no videobook.

# %%
# Definindo os Parâmetros do Fine-Tuning Supervisionado
sft_config = SFTConfig(per_device_train_batch_size = 2,
                       gradient_accumulation_steps = 4,
                       warmup_steps = 5,
                       num_train_epochs = 1,
                       learning_rate = 2e-4,
                       fp16 = True,
                       logging_steps = 1,
                       optim = "adamw_8bit",
                       weight_decay = 0.01,
                       lr_scheduler_type = "linear",
                       seed = 3407,
                       output_dir = "outputs",
                       report_to = "none",
                       dataset_text_field = "train",
                       packing = False)

# %%
# Definindo os Parâmetros do Fine-Tuning Supervisionado (requer os parâmetros gerais no sft_config acima)
dsa_trainer = SFTTrainer(model = modelo,
                         train_dataset = dataset_carregado['train'],
                         peft_config = peft_config,
                         args = sft_config)
# Out:
# Adding EOS to train dataset:   0%|          | 0/17057 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/17057 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/17057 [00:00<?, ? examples/s]

# %% [markdown]
# https://huggingface.co/docs/trl/en/sft_trainer

# %% [markdown]
# > Treinamento do Modelo com o Ajuste Fino

# %%
# %%time
dsa_trainer.train()
# Out:
# {'loss': 0.9522, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 786.0, 'mean_token_accuracy': 0.3002595081925392, 'epoch': 0.00046898815804900925}
# {'loss': 0.8503, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1752.0, 'mean_token_accuracy': 0.280731949955225, 'epoch': 0.0009379763160980185}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 2904.0, 'mean_token_accuracy': 0.2902160510420799, 'epoch': 0.0014069644741470278}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 3516.0, 'mean_token_accuracy': 0.24193474650382996, 'epoch': 0.001875952632196037}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 4431.0, 'mean_token_accuracy': 0.2713005356490612, 'epoch': 0.0023449407902450463}
# {'loss': 0.4867, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 5104.0, 'mean_token_accuracy': 0.19513889029622078, 'epoch': 0.0028139289482940555}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 5980.0, 'mean_token_accuracy': 0.3211020976305008, 'epoch': 0.0032829171063430648}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 6701.0, 'mean_token_accuracy': 0.33092688769102097, 'epoch': 0.003751905264392074}
# {'loss': 1.4559, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 7575.0, 'mean_token_accuracy': 0.29191237315535545, 'epoch': 0.004220893422441084}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 8619.0, 'mean_token_accuracy': 0.3454585671424866, 'epoch': 0.0046898815804900925}
# {'loss': 0.6921, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 9115.0, 'mean_token_accuracy': 0.22788738831877708, 'epoch': 0.005158869738539102}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 9664.0, 'mean_token_accuracy': 0.24841224402189255, 'epoch': 0.005627857896588111}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 10617.0, 'mean_token_accuracy': 0.30242759734392166, 'epoch': 0.006096846054637121}
# {'loss': 1.9047, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 11435.0, 'mean_token_accuracy': 0.2865426614880562, 'epoch': 0.0065658342126861296}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 12082.0, 'mean_token_accuracy': 0.30845604091882706, 'epoch': 0.007034822370735139}
# {'loss': 4.311, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 12734.0, 'mean_token_accuracy': 0.3252117745578289, 'epoch': 0.007503810528784148}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 13332.0, 'mean_token_accuracy': 0.31917980313301086, 'epoch': 0.007972798686833158}
# {'loss': 6.4014, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 13586.0, 'mean_token_accuracy': 0.23003471828997135, 'epoch': 0.008441786844882167}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 14343.0, 'mean_token_accuracy': 0.31275901570916176, 'epoch': 0.008910775002931175}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 14934.0, 'mean_token_accuracy': 0.28588705882430077, 'epoch': 0.009379763160980185}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 15585.0, 'mean_token_accuracy': 0.2783602215349674, 'epoch': 0.009848751319029195}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 17263.0, 'mean_token_accuracy': 0.3237333372235298, 'epoch': 0.010317739477078204}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 17980.0, 'mean_token_accuracy': 0.2626906596124172, 'epoch': 0.010786727635127212}
# {'loss': 2.9562, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 18623.0, 'mean_token_accuracy': 0.31328195333480835, 'epoch': 0.011255715793176222}
# {'loss': 3.0175, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 20560.0, 'mean_token_accuracy': 0.33452391996979713, 'epoch': 0.011724703951225232}
# {'loss': 3.6374, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 21622.0, 'mean_token_accuracy': 0.29186806827783585, 'epoch': 0.012193692109274241}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 22657.0, 'mean_token_accuracy': 0.3655380830168724, 'epoch': 0.01266268026732325}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 23742.0, 'mean_token_accuracy': 0.35295337438583374, 'epoch': 0.013131668425372259}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 25170.0, 'mean_token_accuracy': 0.35428640991449356, 'epoch': 0.013600656583421269}
# {'loss': 0.4226, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 25948.0, 'mean_token_accuracy': 0.29952065274119377, 'epoch': 0.014069644741470278}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 26494.0, 'mean_token_accuracy': 0.2868211790919304, 'epoch': 0.014538632899519286}
# {'loss': 0.52, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 28607.0, 'mean_token_accuracy': 0.33291270583868027, 'epoch': 0.015007621057568296}
# {'loss': 3.6581, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 29173.0, 'mean_token_accuracy': 0.23980183899402618, 'epoch': 0.015476609215617306}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 30557.0, 'mean_token_accuracy': 0.30880550295114517, 'epoch': 0.015945597373666315}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 31668.0, 'mean_token_accuracy': 0.37073197215795517, 'epoch': 0.016414585531715323}
# {'loss': 2.5714, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 32577.0, 'mean_token_accuracy': 0.2671441622078419, 'epoch': 0.016883573689764335}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 33684.0, 'mean_token_accuracy': 0.37838931381702423, 'epoch': 0.017352561847813343}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 34254.0, 'mean_token_accuracy': 0.24997829645872116, 'epoch': 0.01782155000586235}
# {'loss': 2.5359, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 34839.0, 'mean_token_accuracy': 0.30666060373187065, 'epoch': 0.018290538163911362}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 35519.0, 'mean_token_accuracy': 0.26642750948667526, 'epoch': 0.01875952632196037}
# {'loss': 0.7237, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 36822.0, 'mean_token_accuracy': 0.276906106621027, 'epoch': 0.019228514480009378}
# {'loss': 4.8661, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 37332.0, 'mean_token_accuracy': 0.28881129063665867, 'epoch': 0.01969750263805839}
# {'loss': 9.5161, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 38101.0, 'mean_token_accuracy': 0.2480184268206358, 'epoch': 0.020166490796107397}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 39441.0, 'mean_token_accuracy': 0.35149408876895905, 'epoch': 0.02063547895415641}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 41465.0, 'mean_token_accuracy': 0.3427352160215378, 'epoch': 0.021104467112205417}
# {'loss': 1.3911, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 42843.0, 'mean_token_accuracy': 0.35740022361278534, 'epoch': 0.021573455270254425}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 44102.0, 'mean_token_accuracy': 0.3135666809976101, 'epoch': 0.022042443428303436}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 44940.0, 'mean_token_accuracy': 0.29224414750933647, 'epoch': 0.022511431586352444}
# {'loss': 0.9047, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 45449.0, 'mean_token_accuracy': 0.20768996141850948, 'epoch': 0.022980419744401452}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 46418.0, 'mean_token_accuracy': 0.31729088351130486, 'epoch': 0.023449407902450464}
# {'loss': 4.5484, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 46953.0, 'mean_token_accuracy': 0.30501173436641693, 'epoch': 0.02391839606049947}
# {'loss': 0.93, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 47749.0, 'mean_token_accuracy': 0.3406589701771736, 'epoch': 0.024387384218548483}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 48545.0, 'mean_token_accuracy': 0.30506882816553116, 'epoch': 0.02485637237659749}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 49117.0, 'mean_token_accuracy': 0.2413516826927662, 'epoch': 0.0253253605346465}
# {'loss': 2.2666, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 49878.0, 'mean_token_accuracy': 0.27266236022114754, 'epoch': 0.02579434869269551}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 50415.0, 'mean_token_accuracy': 0.2181193344295025, 'epoch': 0.026263336850744518}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 51735.0, 'mean_token_accuracy': 0.34856610000133514, 'epoch': 0.02673232500879353}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 52379.0, 'mean_token_accuracy': 0.2741391994059086, 'epoch': 0.027201313166842538}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 53656.0, 'mean_token_accuracy': 0.30679602921009064, 'epoch': 0.027670301324891546}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 54179.0, 'mean_token_accuracy': 0.26461249217391014, 'epoch': 0.028139289482940557}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 55257.0, 'mean_token_accuracy': 0.2853717990219593, 'epoch': 0.028608277640989565}
# {'loss': 0.3576, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 56154.0, 'mean_token_accuracy': 0.20535662025213242, 'epoch': 0.029077265799038573}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 57063.0, 'mean_token_accuracy': 0.3159051388502121, 'epoch': 0.029546253957087584}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 57654.0, 'mean_token_accuracy': 0.31471923738718033, 'epoch': 0.030015242115136592}
# {'loss': 3.602, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 58601.0, 'mean_token_accuracy': 0.3637562543153763, 'epoch': 0.030484230273185604}
# {'loss': 3.6474, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 59242.0, 'mean_token_accuracy': 0.2686392590403557, 'epoch': 0.03095321843123461}
# {'loss': 1.1181, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 60257.0, 'mean_token_accuracy': 0.28114741668105125, 'epoch': 0.03142220658928362}
# {'loss': 4.6664, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 60828.0, 'mean_token_accuracy': 0.23390220664441586, 'epoch': 0.03189119474733263}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 62242.0, 'mean_token_accuracy': 0.28821441531181335, 'epoch': 0.03236018290538164}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 63015.0, 'mean_token_accuracy': 0.24218659102916718, 'epoch': 0.03282917106343065}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 63654.0, 'mean_token_accuracy': 0.32468798011541367, 'epoch': 0.033298159221479655}
# {'loss': 2.8603, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 64414.0, 'mean_token_accuracy': 0.32226768136024475, 'epoch': 0.03376714737952867}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 66136.0, 'mean_token_accuracy': 0.3076487183570862, 'epoch': 0.03423613553757768}
# {'loss': 0.7328, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 66995.0, 'mean_token_accuracy': 0.3296402543783188, 'epoch': 0.034705123695626686}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 67587.0, 'mean_token_accuracy': 0.2830672226846218, 'epoch': 0.035174111853675694}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 68631.0, 'mean_token_accuracy': 0.3084005042910576, 'epoch': 0.0356431000117247}
# {'loss': 1.3415, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 69378.0, 'mean_token_accuracy': 0.31487415730953217, 'epoch': 0.036112088169773716}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 70161.0, 'mean_token_accuracy': 0.3653878755867481, 'epoch': 0.036581076327822724}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 71210.0, 'mean_token_accuracy': 0.2923564426600933, 'epoch': 0.03705006448587173}
# {'loss': 3.3396, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 72025.0, 'mean_token_accuracy': 0.24554764479398727, 'epoch': 0.03751905264392074}
# {'loss': 1.5183, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 72610.0, 'mean_token_accuracy': 0.31341004744172096, 'epoch': 0.03798804080196975}
# {'loss': 0.8457, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 73310.0, 'mean_token_accuracy': 0.2695556730031967, 'epoch': 0.038457028960018756}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 74206.0, 'mean_token_accuracy': 0.30207639187574387, 'epoch': 0.03892601711806777}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 74749.0, 'mean_token_accuracy': 0.3612977862358093, 'epoch': 0.03939500527611678}
# {'loss': 1.7646, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 75414.0, 'mean_token_accuracy': 0.2608373984694481, 'epoch': 0.03986399343416579}
# {'loss': 3.2015, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 75834.0, 'mean_token_accuracy': 0.2290983982384205, 'epoch': 0.040332981592214795}
# {'loss': 1.619, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 76501.0, 'mean_token_accuracy': 0.28889942169189453, 'epoch': 0.0408019697502638}
# {'loss': 0.7617, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 77107.0, 'mean_token_accuracy': 0.34480471163988113, 'epoch': 0.04127095790831282}
# {'loss': 6.7065, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 77865.0, 'mean_token_accuracy': 0.2833382226526737, 'epoch': 0.041739946066361826}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 78877.0, 'mean_token_accuracy': 0.30519071966409683, 'epoch': 0.042208934224410834}
# {'loss': 2.6595, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 79802.0, 'mean_token_accuracy': 0.21701638028025627, 'epoch': 0.04267792238245984}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 80833.0, 'mean_token_accuracy': 0.32300106063485146, 'epoch': 0.04314691054050885}
# {'loss': 2.6905, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 81998.0, 'mean_token_accuracy': 0.3288555443286896, 'epoch': 0.043615898698557864}
# {'loss': 1.6128, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 83404.0, 'mean_token_accuracy': 0.22725326754152775, 'epoch': 0.04408488685660687}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 84167.0, 'mean_token_accuracy': 0.37892069295048714, 'epoch': 0.04455387501465588}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 84646.0, 'mean_token_accuracy': 0.25800939463078976, 'epoch': 0.04502286317270489}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 85645.0, 'mean_token_accuracy': 0.25435681641101837, 'epoch': 0.045491851330753896}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 86610.0, 'mean_token_accuracy': 0.29024621471762657, 'epoch': 0.045960839488802904}
# {'loss': 4.7466, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 87488.0, 'mean_token_accuracy': 0.34167496114969254, 'epoch': 0.04642982764685192}
# {'loss': 1.5913, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 88050.0, 'mean_token_accuracy': 0.34624504670500755, 'epoch': 0.04689881580490093}
# {'loss': 0.5094, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 89621.0, 'mean_token_accuracy': 0.33184269443154335, 'epoch': 0.047367803962949935}
# {'loss': 1.2988, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 90193.0, 'mean_token_accuracy': 0.28708844631910324, 'epoch': 0.04783679212099894}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 91167.0, 'mean_token_accuracy': 0.31130799651145935, 'epoch': 0.04830578027904795}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 91771.0, 'mean_token_accuracy': 0.32036662474274635, 'epoch': 0.048774768437096966}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 92936.0, 'mean_token_accuracy': 0.29812248796224594, 'epoch': 0.049243756595145974}
# {'loss': 2.7647, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 93536.0, 'mean_token_accuracy': 0.24255946651101112, 'epoch': 0.04971274475319498}
# {'loss': 2.322, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 94205.0, 'mean_token_accuracy': 0.2838473692536354, 'epoch': 0.05018173291124399}
# {'loss': 5.4243, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 94684.0, 'mean_token_accuracy': 0.3087940253317356, 'epoch': 0.050650721069293}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 95605.0, 'mean_token_accuracy': 0.28217407315969467, 'epoch': 0.05111970922734201}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 96958.0, 'mean_token_accuracy': 0.3458882346749306, 'epoch': 0.05158869738539102}
# {'loss': 1.0517, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 98366.0, 'mean_token_accuracy': 0.28851836547255516, 'epoch': 0.05205768554344003}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 99391.0, 'mean_token_accuracy': 0.36818210035562515, 'epoch': 0.052526673701489036}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 100126.0, 'mean_token_accuracy': 0.2775403633713722, 'epoch': 0.052995661859538044}
# {'loss': 0.4599, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 100729.0, 'mean_token_accuracy': 0.27394284307956696, 'epoch': 0.05346465001758706}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 101886.0, 'mean_token_accuracy': 0.34208500012755394, 'epoch': 0.05393363817563607}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 102871.0, 'mean_token_accuracy': 0.27128952369093895, 'epoch': 0.054402626333685075}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 103838.0, 'mean_token_accuracy': 0.26214244589209557, 'epoch': 0.05487161449173408}
# {'loss': 1.464, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 104648.0, 'mean_token_accuracy': 0.2867950350046158, 'epoch': 0.05534060264978309}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 105289.0, 'mean_token_accuracy': 0.25660089775919914, 'epoch': 0.0558095908078321}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 105863.0, 'mean_token_accuracy': 0.23610759526491165, 'epoch': 0.056278578965881114}
# {'loss': 1.3313, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 106625.0, 'mean_token_accuracy': 0.3081413172185421, 'epoch': 0.05674756712393012}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 107553.0, 'mean_token_accuracy': 0.24441469833254814, 'epoch': 0.05721655528197913}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 108364.0, 'mean_token_accuracy': 0.2459721602499485, 'epoch': 0.05768554344002814}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 109170.0, 'mean_token_accuracy': 0.2974703162908554, 'epoch': 0.058154531598077146}
# {'loss': 0.9993, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 109846.0, 'mean_token_accuracy': 0.33734212070703506, 'epoch': 0.05862351975612616}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 110425.0, 'mean_token_accuracy': 0.2958293557167053, 'epoch': 0.05909250791417517}
# {'loss': 2.2361, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 111475.0, 'mean_token_accuracy': 0.24256591498851776, 'epoch': 0.059561496072224177}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 112060.0, 'mean_token_accuracy': 0.26479651033878326, 'epoch': 0.060030484230273184}
# {'loss': 0.7394, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 113429.0, 'mean_token_accuracy': 0.36298976093530655, 'epoch': 0.06049947238832219}
# {'loss': 0.8111, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 114242.0, 'mean_token_accuracy': 0.20738916844129562, 'epoch': 0.06096846054637121}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 115160.0, 'mean_token_accuracy': 0.3123881071805954, 'epoch': 0.061437448704420215}
# {'loss': 0.935, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 115615.0, 'mean_token_accuracy': 0.25543122738599777, 'epoch': 0.06190643686246922}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 116093.0, 'mean_token_accuracy': 0.31651144474744797, 'epoch': 0.06237542502051823}
# {'loss': 5.0222, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 116574.0, 'mean_token_accuracy': 0.252513762563467, 'epoch': 0.06284441317856725}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 117796.0, 'mean_token_accuracy': 0.29917365312576294, 'epoch': 0.06331340133661625}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 119086.0, 'mean_token_accuracy': 0.2645857445895672, 'epoch': 0.06378238949466526}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 119998.0, 'mean_token_accuracy': 0.29746798053383827, 'epoch': 0.06425137765271427}
# {'loss': 2.0513, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 120671.0, 'mean_token_accuracy': 0.3403605483472347, 'epoch': 0.06472036581076328}
# {'loss': 1.8496, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 121514.0, 'mean_token_accuracy': 0.2912479601800442, 'epoch': 0.06518935396881229}
# {'loss': 0.4296, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 122281.0, 'mean_token_accuracy': 0.27105807699263096, 'epoch': 0.0656583421268613}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 123744.0, 'mean_token_accuracy': 0.2711257375776768, 'epoch': 0.0661273302849103}
# {'loss': 6.4607, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 124175.0, 'mean_token_accuracy': 0.23552243039011955, 'epoch': 0.06659631844295931}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 125392.0, 'mean_token_accuracy': 0.3424460291862488, 'epoch': 0.06706530660100832}
# {'loss': 1.3352, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 127063.0, 'mean_token_accuracy': 0.31707141920924187, 'epoch': 0.06753429475905734}
# {'loss': 0.339, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 128412.0, 'mean_token_accuracy': 0.2943230830132961, 'epoch': 0.06800328291710635}
# {'loss': 0.355, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 129315.0, 'mean_token_accuracy': 0.25382789224386215, 'epoch': 0.06847227107515536}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 130211.0, 'mean_token_accuracy': 0.24169501662254333, 'epoch': 0.06894125923320436}
# {'loss': 4.0071, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 131023.0, 'mean_token_accuracy': 0.26759757101535797, 'epoch': 0.06941024739125337}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 131823.0, 'mean_token_accuracy': 0.24084554612636566, 'epoch': 0.06987923554930238}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 133547.0, 'mean_token_accuracy': 0.2940834201872349, 'epoch': 0.07034822370735139}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 134988.0, 'mean_token_accuracy': 0.362013753503561, 'epoch': 0.0708172118654004}
# {'loss': 2.5, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 135480.0, 'mean_token_accuracy': 0.28519028425216675, 'epoch': 0.0712862000234494}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 136235.0, 'mean_token_accuracy': 0.2541455030441284, 'epoch': 0.07175518818149841}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 137853.0, 'mean_token_accuracy': 0.32792285829782486, 'epoch': 0.07222417633954743}
# {'loss': 0.8962, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 139607.0, 'mean_token_accuracy': 0.3657740503549576, 'epoch': 0.07269316449759644}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 140644.0, 'mean_token_accuracy': 0.28695080429315567, 'epoch': 0.07316215265564545}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 141469.0, 'mean_token_accuracy': 0.2935272231698036, 'epoch': 0.07363114081369446}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 142797.0, 'mean_token_accuracy': 0.27923115342855453, 'epoch': 0.07410012897174346}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 144523.0, 'mean_token_accuracy': 0.3389577083289623, 'epoch': 0.07456911712979247}
# {'loss': 6.0851, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 145126.0, 'mean_token_accuracy': 0.2770675718784332, 'epoch': 0.07503810528784148}
# {'loss': 8.1617, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 146314.0, 'mean_token_accuracy': 0.40079496800899506, 'epoch': 0.07550709344589049}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 147511.0, 'mean_token_accuracy': 0.29398179054260254, 'epoch': 0.0759760816039395}
# {'loss': 4.1917, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 148396.0, 'mean_token_accuracy': 0.3076840154826641, 'epoch': 0.0764450697619885}
# {'loss': 3.9945, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 149020.0, 'mean_token_accuracy': 0.2777310647070408, 'epoch': 0.07691405792003751}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 150646.0, 'mean_token_accuracy': 0.30110082402825356, 'epoch': 0.07738304607808653}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 152456.0, 'mean_token_accuracy': 0.3115241639316082, 'epoch': 0.07785203423613554}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 153059.0, 'mean_token_accuracy': 0.28098393231630325, 'epoch': 0.07832102239418455}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 154287.0, 'mean_token_accuracy': 0.32943233847618103, 'epoch': 0.07879001055223356}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 154964.0, 'mean_token_accuracy': 0.24187901988625526, 'epoch': 0.07925899871028257}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 155486.0, 'mean_token_accuracy': 0.2441711537539959, 'epoch': 0.07972798686833157}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 156033.0, 'mean_token_accuracy': 0.23616497591137886, 'epoch': 0.08019697502638058}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 158068.0, 'mean_token_accuracy': 0.26555975899100304, 'epoch': 0.08066596318442959}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 158884.0, 'mean_token_accuracy': 0.24691098928451538, 'epoch': 0.0811349513424786}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 159927.0, 'mean_token_accuracy': 0.3562946543097496, 'epoch': 0.0816039395005276}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 160839.0, 'mean_token_accuracy': 0.2864327095448971, 'epoch': 0.08207292765857663}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 161482.0, 'mean_token_accuracy': 0.28021662682294846, 'epoch': 0.08254191581662564}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 162659.0, 'mean_token_accuracy': 0.28486965596675873, 'epoch': 0.08301090397467464}
# {'loss': 1.4236, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 163527.0, 'mean_token_accuracy': 0.24904291331768036, 'epoch': 0.08347989213272365}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 164367.0, 'mean_token_accuracy': 0.2727605141699314, 'epoch': 0.08394888029077266}
# {'loss': 0.1943, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 166106.0, 'mean_token_accuracy': 0.31354841589927673, 'epoch': 0.08441786844882167}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 167272.0, 'mean_token_accuracy': 0.3150150440633297, 'epoch': 0.08488685660687068}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 168711.0, 'mean_token_accuracy': 0.30635491013526917, 'epoch': 0.08535584476491968}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 169637.0, 'mean_token_accuracy': 0.2782514840364456, 'epoch': 0.08582483292296869}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 170625.0, 'mean_token_accuracy': 0.2608180120587349, 'epoch': 0.0862938210810177}
# {'loss': 1.3263, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 171440.0, 'mean_token_accuracy': 0.24241639859974384, 'epoch': 0.08676280923906671}
# {'loss': 0.5736, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 172326.0, 'mean_token_accuracy': 0.26546452194452286, 'epoch': 0.08723179739711573}
# {'loss': 0.5776, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 172792.0, 'mean_token_accuracy': 0.1918331477791071, 'epoch': 0.08770078555516474}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 173484.0, 'mean_token_accuracy': 0.2646690122783184, 'epoch': 0.08816977371321374}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 174679.0, 'mean_token_accuracy': 0.30749010667204857, 'epoch': 0.08863876187126275}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 175736.0, 'mean_token_accuracy': 0.29194609075784683, 'epoch': 0.08910775002931176}
# {'loss': 0.4733, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 176788.0, 'mean_token_accuracy': 0.316389761865139, 'epoch': 0.08957673818736077}
# {'loss': 3.2142, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 177792.0, 'mean_token_accuracy': 0.30978601425886154, 'epoch': 0.09004572634540978}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 178603.0, 'mean_token_accuracy': 0.2513984590768814, 'epoch': 0.09051471450345878}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 179532.0, 'mean_token_accuracy': 0.31747348979115486, 'epoch': 0.09098370266150779}
# {'loss': 3.5907, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 180428.0, 'mean_token_accuracy': 0.3158240094780922, 'epoch': 0.0914526908195568}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 181249.0, 'mean_token_accuracy': 0.2881399430334568, 'epoch': 0.09192167897760581}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 182522.0, 'mean_token_accuracy': 0.3216470405459404, 'epoch': 0.09239066713565483}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 184757.0, 'mean_token_accuracy': 0.35567838698625565, 'epoch': 0.09285965529370384}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 185734.0, 'mean_token_accuracy': 0.3101284131407738, 'epoch': 0.09332864345175285}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 186549.0, 'mean_token_accuracy': 0.27904126420617104, 'epoch': 0.09379763160980185}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 187000.0, 'mean_token_accuracy': 0.24255678802728653, 'epoch': 0.09426661976785086}
# {'loss': 2.9458, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 187569.0, 'mean_token_accuracy': 0.232478067278862, 'epoch': 0.09473560792589987}
# {'loss': 5.5818, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 188291.0, 'mean_token_accuracy': 0.35450468212366104, 'epoch': 0.09520459608394888}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 188823.0, 'mean_token_accuracy': 0.24995705485343933, 'epoch': 0.09567358424199789}
# {'loss': 0.7943, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 189789.0, 'mean_token_accuracy': 0.32295141369104385, 'epoch': 0.0961425724000469}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 190687.0, 'mean_token_accuracy': 0.30677274987101555, 'epoch': 0.0966115605580959}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 191674.0, 'mean_token_accuracy': 0.29001104831695557, 'epoch': 0.09708054871614492}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 192499.0, 'mean_token_accuracy': 0.2927820682525635, 'epoch': 0.09754953687419393}
# {'loss': 4.6806, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 193254.0, 'mean_token_accuracy': 0.2607371062040329, 'epoch': 0.09801852503224294}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 194189.0, 'mean_token_accuracy': 0.3090919218957424, 'epoch': 0.09848751319029195}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 195113.0, 'mean_token_accuracy': 0.22657959908246994, 'epoch': 0.09895650134834096}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 195835.0, 'mean_token_accuracy': 0.26451366394758224, 'epoch': 0.09942548950638996}
# {'loss': 0.8584, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 197274.0, 'mean_token_accuracy': 0.30203045532107353, 'epoch': 0.09989447766443897}
# {'loss': 1.1164, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 197951.0, 'mean_token_accuracy': 0.33691345527768135, 'epoch': 0.10036346582248798}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 198755.0, 'mean_token_accuracy': 0.3046391196548939, 'epoch': 0.10083245398053699}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 199809.0, 'mean_token_accuracy': 0.3164820522069931, 'epoch': 0.101301442138586}
# {'loss': 6.0129, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 200486.0, 'mean_token_accuracy': 0.24630627036094666, 'epoch': 0.101770430296635}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 201395.0, 'mean_token_accuracy': 0.27742309868335724, 'epoch': 0.10223941845468403}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 202282.0, 'mean_token_accuracy': 0.23348038271069527, 'epoch': 0.10270840661273303}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 203406.0, 'mean_token_accuracy': 0.282238382846117, 'epoch': 0.10317739477078204}
# {'loss': 0.4439, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 204559.0, 'mean_token_accuracy': 0.31668761745095253, 'epoch': 0.10364638292883105}
# {'loss': 1.8944, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 205033.0, 'mean_token_accuracy': 0.24406437575817108, 'epoch': 0.10411537108688006}
# {'loss': 8.2951, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 205500.0, 'mean_token_accuracy': 0.2489878050982952, 'epoch': 0.10458435924492906}
# {'loss': 0.5321, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 206270.0, 'mean_token_accuracy': 0.31122415885329247, 'epoch': 0.10505334740297807}
# {'loss': 4.0995, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 206943.0, 'mean_token_accuracy': 0.28292589262127876, 'epoch': 0.10552233556102708}
# {'loss': 4.8692, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 207815.0, 'mean_token_accuracy': 0.29330335557460785, 'epoch': 0.10599132371907609}
# {'loss': 0.5971, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 208572.0, 'mean_token_accuracy': 0.27683291397988796, 'epoch': 0.1064603118771251}
# {'loss': 0.7984, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 209509.0, 'mean_token_accuracy': 0.27547238022089005, 'epoch': 0.10692930003517412}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 210280.0, 'mean_token_accuracy': 0.2246525101363659, 'epoch': 0.10739828819322313}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 210925.0, 'mean_token_accuracy': 0.27582966536283493, 'epoch': 0.10786727635127213}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 212049.0, 'mean_token_accuracy': 0.28630761429667473, 'epoch': 0.10833626450932114}
# {'loss': 1.512, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 212526.0, 'mean_token_accuracy': 0.24949495121836662, 'epoch': 0.10880525266737015}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 214005.0, 'mean_token_accuracy': 0.3343431130051613, 'epoch': 0.10927424082541916}
# {'loss': 0.5804, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 215192.0, 'mean_token_accuracy': 0.2837723270058632, 'epoch': 0.10974322898346817}
# {'loss': 1.5193, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 216300.0, 'mean_token_accuracy': 0.3389381095767021, 'epoch': 0.11021221714151717}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 217414.0, 'mean_token_accuracy': 0.2574390098452568, 'epoch': 0.11068120529956618}
# {'loss': 1.8978, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 218139.0, 'mean_token_accuracy': 0.33075985312461853, 'epoch': 0.11115019345761519}
# {'loss': 8.6109, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 218985.0, 'mean_token_accuracy': 0.2907075844705105, 'epoch': 0.1116191816156642}
# {'loss': 4.0133, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 219979.0, 'mean_token_accuracy': 0.3383706733584404, 'epoch': 0.11208816977371322}
# {'loss': 7.445, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 220493.0, 'mean_token_accuracy': 0.30017102509737015, 'epoch': 0.11255715793176223}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 221215.0, 'mean_token_accuracy': 0.27222590520977974, 'epoch': 0.11302614608981124}
# {'loss': 4.5042, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 222068.0, 'mean_token_accuracy': 0.33586040139198303, 'epoch': 0.11349513424786024}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 222874.0, 'mean_token_accuracy': 0.32780658453702927, 'epoch': 0.11396412240590925}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 223728.0, 'mean_token_accuracy': 0.29377545416355133, 'epoch': 0.11443311056395826}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 224168.0, 'mean_token_accuracy': 0.18340975046157837, 'epoch': 0.11490209872200727}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 224689.0, 'mean_token_accuracy': 0.32513513788580894, 'epoch': 0.11537108688005628}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 225544.0, 'mean_token_accuracy': 0.24297929927706718, 'epoch': 0.11584007503810528}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 226544.0, 'mean_token_accuracy': 0.3394319713115692, 'epoch': 0.11630906319615429}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 227894.0, 'mean_token_accuracy': 0.312310840934515, 'epoch': 0.11677805135420331}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 229119.0, 'mean_token_accuracy': 0.23976091668009758, 'epoch': 0.11724703951225232}
# {'loss': 0.261, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 230209.0, 'mean_token_accuracy': 0.285652220249176, 'epoch': 0.11771602767030133}
# {'loss': 1.1843, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 231177.0, 'mean_token_accuracy': 0.3315713554620743, 'epoch': 0.11818501582835034}
# {'loss': 3.8594, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 231771.0, 'mean_token_accuracy': 0.30217524990439415, 'epoch': 0.11865400398639935}
# {'loss': 1.4166, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 233019.0, 'mean_token_accuracy': 0.2870338670909405, 'epoch': 0.11912299214444835}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 233751.0, 'mean_token_accuracy': 0.3509202226996422, 'epoch': 0.11959198030249736}
# {'loss': 5.0652, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 234468.0, 'mean_token_accuracy': 0.2507111467421055, 'epoch': 0.12006096846054637}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 235667.0, 'mean_token_accuracy': 0.3397076427936554, 'epoch': 0.12052995661859538}
# {'loss': 2.7065, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 236308.0, 'mean_token_accuracy': 0.32735737785696983, 'epoch': 0.12099894477664438}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 237379.0, 'mean_token_accuracy': 0.3237600810825825, 'epoch': 0.12146793293469339}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 238231.0, 'mean_token_accuracy': 0.3180684298276901, 'epoch': 0.12193692109274241}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 240321.0, 'mean_token_accuracy': 0.30987462401390076, 'epoch': 0.12240590925079142}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 241858.0, 'mean_token_accuracy': 0.3195982649922371, 'epoch': 0.12287489740884043}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 243609.0, 'mean_token_accuracy': 0.38177721202373505, 'epoch': 0.12334388556688944}
# {'loss': 7.4591, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 243954.0, 'mean_token_accuracy': 0.2625354863703251, 'epoch': 0.12381287372493845}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 244507.0, 'mean_token_accuracy': 0.25018227845430374, 'epoch': 0.12428186188298745}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 245986.0, 'mean_token_accuracy': 0.29994067922234535, 'epoch': 0.12475085004103646}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 247130.0, 'mean_token_accuracy': 0.30642664432525635, 'epoch': 0.12521983819908547}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 248797.0, 'mean_token_accuracy': 0.4091886803507805, 'epoch': 0.1256888263571345}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 249475.0, 'mean_token_accuracy': 0.24156032875180244, 'epoch': 0.1261578145151835}
# {'loss': 0.6722, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 250877.0, 'mean_token_accuracy': 0.41464535146951675, 'epoch': 0.1266268026732325}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 251385.0, 'mean_token_accuracy': 0.2601281702518463, 'epoch': 0.1270957908312815}
# {'loss': 0.9232, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 252642.0, 'mean_token_accuracy': 0.3746310919523239, 'epoch': 0.12756477898933052}
# {'loss': 2.9007, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 253288.0, 'mean_token_accuracy': 0.27751540392637253, 'epoch': 0.12803376714737952}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 254603.0, 'mean_token_accuracy': 0.3224761001765728, 'epoch': 0.12850275530542854}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 255297.0, 'mean_token_accuracy': 0.25014836713671684, 'epoch': 0.12897174346347753}
# {'loss': 6.0074, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 256258.0, 'mean_token_accuracy': 0.3158522918820381, 'epoch': 0.12944073162152656}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 257302.0, 'mean_token_accuracy': 0.29459280520677567, 'epoch': 0.12990971977957558}
# {'loss': 0.8298, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 258410.0, 'mean_token_accuracy': 0.34076007455587387, 'epoch': 0.13037870793762457}
# {'loss': 1.0475, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 259210.0, 'mean_token_accuracy': 0.3282541483640671, 'epoch': 0.1308476960956736}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 260025.0, 'mean_token_accuracy': 0.28364473581314087, 'epoch': 0.1313166842537226}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 262008.0, 'mean_token_accuracy': 0.39266129583120346, 'epoch': 0.1317856724117716}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 262718.0, 'mean_token_accuracy': 0.2628217153251171, 'epoch': 0.1322546605698206}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 263639.0, 'mean_token_accuracy': 0.3185538090765476, 'epoch': 0.13272364872786963}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 264435.0, 'mean_token_accuracy': 0.30442240834236145, 'epoch': 0.13319263688591862}
# {'loss': 6.1565, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 264949.0, 'mean_token_accuracy': 0.2816019430756569, 'epoch': 0.13366162504396764}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 266070.0, 'mean_token_accuracy': 0.2649964652955532, 'epoch': 0.13413061320201664}
# {'loss': 2.1566, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 266406.0, 'mean_token_accuracy': 0.2266431450843811, 'epoch': 0.13459960136006566}
# {'loss': 7.6861, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 267256.0, 'mean_token_accuracy': 0.35238778591156006, 'epoch': 0.13506858951811468}
# {'loss': 1.5789, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 268775.0, 'mean_token_accuracy': 0.2593866027891636, 'epoch': 0.13553757767616367}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 269676.0, 'mean_token_accuracy': 0.34487613663077354, 'epoch': 0.1360065658342127}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 270298.0, 'mean_token_accuracy': 0.22009025141596794, 'epoch': 0.1364755539922617}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 270988.0, 'mean_token_accuracy': 0.34052617102861404, 'epoch': 0.1369445421503107}
# {'loss': 5.7139, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 271502.0, 'mean_token_accuracy': 0.25600920990109444, 'epoch': 0.1374135303083597}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 272474.0, 'mean_token_accuracy': 0.34794018417596817, 'epoch': 0.13788251846640873}
# {'loss': 4.4357, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 273540.0, 'mean_token_accuracy': 0.3657200187444687, 'epoch': 0.13835150662445772}
# {'loss': 1.036, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 275051.0, 'mean_token_accuracy': 0.3925229012966156, 'epoch': 0.13882049478250674}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 275628.0, 'mean_token_accuracy': 0.2633139491081238, 'epoch': 0.13928948294055576}
# {'loss': 1.1491, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 276304.0, 'mean_token_accuracy': 0.2904285714030266, 'epoch': 0.13975847109860476}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 277193.0, 'mean_token_accuracy': 0.253402978181839, 'epoch': 0.14022745925665378}
# {'loss': 4.6453, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 277667.0, 'mean_token_accuracy': 0.2590363956987858, 'epoch': 0.14069644741470277}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 278328.0, 'mean_token_accuracy': 0.2846124470233917, 'epoch': 0.1411654355727518}
# {'loss': 0.5388, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 278961.0, 'mean_token_accuracy': 0.2852865010499954, 'epoch': 0.1416344237308008}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 279836.0, 'mean_token_accuracy': 0.2580592408776283, 'epoch': 0.1421034118888498}
# {'loss': 6.9647, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 281365.0, 'mean_token_accuracy': 0.3315970376133919, 'epoch': 0.1425724000468988}
# {'loss': 0.7221, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 282339.0, 'mean_token_accuracy': 0.2761269174516201, 'epoch': 0.14304138820494783}
# {'loss': 4.5363, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 283245.0, 'mean_token_accuracy': 0.34210674464702606, 'epoch': 0.14351037636299682}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 283850.0, 'mean_token_accuracy': 0.2556565888226032, 'epoch': 0.14397936452104584}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 284612.0, 'mean_token_accuracy': 0.3075624331831932, 'epoch': 0.14444835267909487}
# {'loss': 0.4711, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 285265.0, 'mean_token_accuracy': 0.27117299661040306, 'epoch': 0.14491734083714386}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 285803.0, 'mean_token_accuracy': 0.29576370120048523, 'epoch': 0.14538632899519288}
# {'loss': 4.158, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 286470.0, 'mean_token_accuracy': 0.32133759558200836, 'epoch': 0.14585531715324188}
# {'loss': 2.1378, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 287556.0, 'mean_token_accuracy': 0.3416525311768055, 'epoch': 0.1463243053112909}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 288222.0, 'mean_token_accuracy': 0.22626588493585587, 'epoch': 0.1467932934693399}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 288872.0, 'mean_token_accuracy': 0.22326282039284706, 'epoch': 0.1472622816273889}
# ...
# {'loss': 2.9686, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1892734.0, 'mean_token_accuracy': 0.3649572283029556, 'epoch': 0.9534529253136358}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1893400.0, 'mean_token_accuracy': 0.3277595825493336, 'epoch': 0.9539219134716849}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1894118.0, 'mean_token_accuracy': 0.2869383729994297, 'epoch': 0.9543909016297338}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1894761.0, 'mean_token_accuracy': 0.2564459592103958, 'epoch': 0.9548598897877829}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1895869.0, 'mean_token_accuracy': 0.2959118187427521, 'epoch': 0.9553288779458319}
# {'loss': 3.3435, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1896506.0, 'mean_token_accuracy': 0.26369650661945343, 'epoch': 0.9557978661038808}
# {'loss': 3.6302, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1897030.0, 'mean_token_accuracy': 0.2896585203707218, 'epoch': 0.9562668542619299}
# {'loss': 6.0068, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1897795.0, 'mean_token_accuracy': 0.30078042298555374, 'epoch': 0.9567358424199789}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1900033.0, 'mean_token_accuracy': 0.31487539783120155, 'epoch': 0.9572048305780279}
# {'loss': 1.1946, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1900720.0, 'mean_token_accuracy': 0.2508171685039997, 'epoch': 0.9576738187360769}
# {'loss': 0.9462, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1901489.0, 'mean_token_accuracy': 0.29763418436050415, 'epoch': 0.9581428068941259}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1902310.0, 'mean_token_accuracy': 0.28698236495256424, 'epoch': 0.958611795052175}
# {'loss': 1.6399, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1903167.0, 'mean_token_accuracy': 0.24873331934213638, 'epoch': 0.9590807832102239}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1904576.0, 'mean_token_accuracy': 0.2984575517475605, 'epoch': 0.9595497713682729}
# {'loss': 1.0009, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1905282.0, 'mean_token_accuracy': 0.2754424586892128, 'epoch': 0.960018759526322}
# {'loss': 3.2522, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1906138.0, 'mean_token_accuracy': 0.305963184684515, 'epoch': 0.960487747684371}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1906735.0, 'mean_token_accuracy': 0.22064850479364395, 'epoch': 0.96095673584242}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1907941.0, 'mean_token_accuracy': 0.33829064667224884, 'epoch': 0.961425724000469}
# {'loss': 2.7836, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1908548.0, 'mean_token_accuracy': 0.2953689396381378, 'epoch': 0.961894712158518}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1909526.0, 'mean_token_accuracy': 0.32473864406347275, 'epoch': 0.962363700316567}
# {'loss': 4.7844, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1910264.0, 'mean_token_accuracy': 0.3376231864094734, 'epoch': 0.962832688474616}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1911439.0, 'mean_token_accuracy': 0.33128076791763306, 'epoch': 0.963301676632665}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1912721.0, 'mean_token_accuracy': 0.29209979623556137, 'epoch': 0.963770664790714}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1913203.0, 'mean_token_accuracy': 0.21426648646593094, 'epoch': 0.964239652948763}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1914242.0, 'mean_token_accuracy': 0.359524741768837, 'epoch': 0.9647086411068121}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1914662.0, 'mean_token_accuracy': 0.2544493153691292, 'epoch': 0.9651776292648611}
# {'loss': 5.1594, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1915917.0, 'mean_token_accuracy': 0.3600570484995842, 'epoch': 0.96564661742291}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1916959.0, 'mean_token_accuracy': 0.2877209782600403, 'epoch': 0.9661156055809591}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1917690.0, 'mean_token_accuracy': 0.35202859342098236, 'epoch': 0.9665845937390081}
# {'loss': 0.8519, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1918377.0, 'mean_token_accuracy': 0.32221898436546326, 'epoch': 0.9670535818970571}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1919375.0, 'mean_token_accuracy': 0.26916293427348137, 'epoch': 0.9675225700551061}
# {'loss': 0.657, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1920137.0, 'mean_token_accuracy': 0.33111603930592537, 'epoch': 0.9679915582131551}
# {'loss': 1.3715, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1921327.0, 'mean_token_accuracy': 0.2346317283809185, 'epoch': 0.9684605463712042}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1922164.0, 'mean_token_accuracy': 0.24659031629562378, 'epoch': 0.9689295345292531}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1922902.0, 'mean_token_accuracy': 0.28105561062693596, 'epoch': 0.9693985226873022}
# {'loss': 1.8024, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1924223.0, 'mean_token_accuracy': 0.35321009904146194, 'epoch': 0.9698675108453512}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1924923.0, 'mean_token_accuracy': 0.28296956792473793, 'epoch': 0.9703364990034001}
# {'loss': 3.6922, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1925576.0, 'mean_token_accuracy': 0.26210544258356094, 'epoch': 0.9708054871614492}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1926254.0, 'mean_token_accuracy': 0.27660264633595943, 'epoch': 0.9712744753194982}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1927012.0, 'mean_token_accuracy': 0.3356616944074631, 'epoch': 0.9717434634775471}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1927720.0, 'mean_token_accuracy': 0.24408471211791039, 'epoch': 0.9722124516355962}
# {'loss': 1.806, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1928711.0, 'mean_token_accuracy': 0.3497408628463745, 'epoch': 0.9726814397936452}
# {'loss': 3.5448, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1929530.0, 'mean_token_accuracy': 0.32151494175195694, 'epoch': 0.9731504279516943}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1930694.0, 'mean_token_accuracy': 0.2909753583371639, 'epoch': 0.9736194161097432}
# {'loss': 3.0165, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1931290.0, 'mean_token_accuracy': 0.27084920555353165, 'epoch': 0.9740884042677922}
# {'loss': 1.7153, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1931910.0, 'mean_token_accuracy': 0.33151619881391525, 'epoch': 0.9745573924258413}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1933151.0, 'mean_token_accuracy': 0.32657988369464874, 'epoch': 0.9750263805838902}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1933916.0, 'mean_token_accuracy': 0.34241802990436554, 'epoch': 0.9754953687419393}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1935207.0, 'mean_token_accuracy': 0.2535828649997711, 'epoch': 0.9759643568999883}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1936201.0, 'mean_token_accuracy': 0.32215332984924316, 'epoch': 0.9764333450580372}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1937365.0, 'mean_token_accuracy': 0.27699340507388115, 'epoch': 0.9769023332160863}
# {'loss': 2.5573, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1938141.0, 'mean_token_accuracy': 0.32263289764523506, 'epoch': 0.9773713213741353}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1939211.0, 'mean_token_accuracy': 0.36040180921554565, 'epoch': 0.9778403095321843}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1940191.0, 'mean_token_accuracy': 0.3116365969181061, 'epoch': 0.9783092976902333}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1941014.0, 'mean_token_accuracy': 0.25660479813814163, 'epoch': 0.9787782858482823}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1941711.0, 'mean_token_accuracy': 0.2541927546262741, 'epoch': 0.9792472740063314}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1942702.0, 'mean_token_accuracy': 0.3592776507139206, 'epoch': 0.9797162621643803}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1943578.0, 'mean_token_accuracy': 0.3468027785420418, 'epoch': 0.9801852503224293}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1944451.0, 'mean_token_accuracy': 0.2871069200336933, 'epoch': 0.9806542384804784}
# {'loss': 0.5478, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1945115.0, 'mean_token_accuracy': 0.3649986460804939, 'epoch': 0.9811232266385274}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1946399.0, 'mean_token_accuracy': 0.33892905712127686, 'epoch': 0.9815922147965764}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1946966.0, 'mean_token_accuracy': 0.2959846928715706, 'epoch': 0.9820612029546254}
# {'loss': 1.3373, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1947948.0, 'mean_token_accuracy': 0.3030742071568966, 'epoch': 0.9825301911126744}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1948801.0, 'mean_token_accuracy': 0.3218006566166878, 'epoch': 0.9829991792707234}
# {'loss': 1.7058, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1949552.0, 'mean_token_accuracy': 0.24848812818527222, 'epoch': 0.9834681674287724}
# {'loss': 2.7567, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1950506.0, 'mean_token_accuracy': 0.35023147612810135, 'epoch': 0.9839371555868215}
# {'loss': 4.2413, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1952338.0, 'mean_token_accuracy': 0.3682894930243492, 'epoch': 0.9844061437448705}
# {'loss': 1.5087, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1953290.0, 'mean_token_accuracy': 0.2765155956149101, 'epoch': 0.9848751319029194}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1954222.0, 'mean_token_accuracy': 0.31365909799933434, 'epoch': 0.9853441200609685}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1955074.0, 'mean_token_accuracy': 0.39012618362903595, 'epoch': 0.9858131082190175}
# {'loss': 0.445, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1955880.0, 'mean_token_accuracy': 0.32279470190405846, 'epoch': 0.9862820963770664}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1957009.0, 'mean_token_accuracy': 0.29667631164193153, 'epoch': 0.9867510845351155}
# {'loss': 4.0213, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1957344.0, 'mean_token_accuracy': 0.18871664255857468, 'epoch': 0.9872200726931645}
# {'loss': 2.5909, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1957905.0, 'mean_token_accuracy': 0.2953277602791786, 'epoch': 0.9876890608512136}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1959508.0, 'mean_token_accuracy': 0.32278966903686523, 'epoch': 0.9881580490092625}
# {'loss': 12.2755, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1960560.0, 'mean_token_accuracy': 0.33969873934984207, 'epoch': 0.9886270371673115}
# {'loss': 2.6648, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1961965.0, 'mean_token_accuracy': 0.34290917962789536, 'epoch': 0.9890960253253606}
# {'loss': 0.5625, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1962932.0, 'mean_token_accuracy': 0.2515077739953995, 'epoch': 0.9895650134834095}
# {'loss': 1.1247, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1963708.0, 'mean_token_accuracy': 0.2945476956665516, 'epoch': 0.9900340016414586}
# {'loss': 4.9662, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1965269.0, 'mean_token_accuracy': 0.34460457041859627, 'epoch': 0.9905029897995076}
# {'loss': 0.6062, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1965976.0, 'mean_token_accuracy': 0.24920803681015968, 'epoch': 0.9909719779575565}
# {'loss': 2.1476, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1966556.0, 'mean_token_accuracy': 0.20902109891176224, 'epoch': 0.9914409661156056}
# {'loss': 0.5569, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1967170.0, 'mean_token_accuracy': 0.2577866241335869, 'epoch': 0.9919099542736546}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1968014.0, 'mean_token_accuracy': 0.2444637417793274, 'epoch': 0.9923789424317035}
# {'loss': 1.2047, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1969100.0, 'mean_token_accuracy': 0.2991226129233837, 'epoch': 0.9928479305897526}
# {'loss': 0.1785, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1971168.0, 'mean_token_accuracy': 0.30893564969301224, 'epoch': 0.9933169187478016}
# {'loss': 0.759, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1972484.0, 'mean_token_accuracy': 0.36983731389045715, 'epoch': 0.9937859069058507}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1973290.0, 'mean_token_accuracy': 0.28220479749143124, 'epoch': 0.9942548950638996}
# {'loss': 7.3558, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1975224.0, 'mean_token_accuracy': 0.2631726749241352, 'epoch': 0.9947238832219486}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1977176.0, 'mean_token_accuracy': 0.30348771438002586, 'epoch': 0.9951928713799977}
# {'loss': 2.5058, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1977718.0, 'mean_token_accuracy': 0.25248196348547935, 'epoch': 0.9956618595380466}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1978584.0, 'mean_token_accuracy': 0.32466115057468414, 'epoch': 0.9961308476960957}
# {'loss': 2.1002, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1979945.0, 'mean_token_accuracy': 0.32953665405511856, 'epoch': 0.9965998358541447}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1980640.0, 'mean_token_accuracy': 0.2088786344975233, 'epoch': 0.9970688240121937}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1982040.0, 'mean_token_accuracy': 0.31524460203945637, 'epoch': 0.9975378121702427}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1982973.0, 'mean_token_accuracy': 0.3314052000641823, 'epoch': 0.9980068003282917}
# {'loss': 1.533, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1983852.0, 'mean_token_accuracy': 0.3150215148925781, 'epoch': 0.9984757884863407}
# {'loss': 5.5871, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1984825.0, 'mean_token_accuracy': 0.3451211228966713, 'epoch': 0.9989447766443897}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1985324.0, 'mean_token_accuracy': 0.3090287782251835, 'epoch': 0.9994137648024387}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1986083.0, 'mean_token_accuracy': 0.2853238359093666, 'epoch': 0.9998827529604878}
# {'loss': 3.6499, 'grad_norm': nan, 'learning_rate': 0.0, 'num_tokens': 1986286.0, 'mean_token_accuracy': 0.41584157943725586, 'epoch': 1.0}
# {'train_runtime': 2400.7478, 'train_samples_per_second': 7.105, 'train_steps_per_second': 0.888, 'train_loss': 1.1741799978906986, 'epoch': 1.0}
# CPU times: user 39min 51s, sys: 12.5 s, total: 40min 4s
# Wall time: 40min 1s
# TrainOutput(global_step=2133, training_loss=1.1741799978906986, metrics={'train_runtime': 2400.7478, 'train_samples_per_second': 7.105, 'train_steps_per_second': 0.888, 'total_flos': 1.1664325609849651e+17, 'train_loss': 1.1741799978906986})

# %%
# Salvando o modelo treinado
dsa_trainer.model.save_pretrained(modelo_dsa)

# %% [markdown]
# <!-- Projeto Desenvolvido na Data Science Academy - www.datascienceacademy.com.br -->

# %%
# Novo texto de entrada
prompt = "It's rare that a movie lives up to its hype, even rarer that the hype is transcended by the actual achievement"

# %% [markdown]
# https://huggingface.co/docs/transformers/en/main_classes/pipelines

# %%
# Pipeline de Análise de Sentimentos com o Modelo Ajustado
pipe = pipeline(task = "text-generation",
                model = modelo,
                tokenizer = tokenizador,
                max_length = 200)

# %%
# Executa o pipeline e extrai o resultado
resultado = pipe(f"<s>[INST] {prompt} [/INST]")

# %%
print(resultado)
# Out:
# [{'generated_text': "<s>[INST] It's rare that a movie lives up to its hype, even rarer that the hype is transcended by the actual achievement [/INST]  I couldn't agree more! It's often the case that movies fail to meet the high expectations set by their marketing campaigns, but when a film manages to exceed those expectations, it's truly special. nobody likes a disappointing movie, but when a film exceeds expectations, it can be a truly magical experience.\n\nThere are several reasons why a movie might live up to or even surpass its hype. Here are a few:\n\n1. Originality: When a movie offers something new and unique, it can generate a lot of buzz and excitement. If the movie delivers on its promise of originality, it can exceed expectations and leave audiences feeling impressed and satisfied.\n2."}]

# %%
print(resultado[0]['generated_text'])
# Out:
# <s>[INST] It's rare that a movie lives up to its hype, even rarer that the hype is transcended by the actual achievement [/INST]  I couldn't agree more! It's often the case that movies fail to meet the high expectations set by their marketing campaigns, but when a film manages to exceed those expectations, it's truly special. nobody likes a disappointing movie, but when a film exceeds expectations, it can be a truly magical experience.
#
# There are several reasons why a movie might live up to or even surpass its hype. Here are a few:
#
# 1. Originality: When a movie offers something new and unique, it can generate a lot of buzz and excitement. If the movie delivers on its promise of originality, it can exceed expectations and leave audiences feeling impressed and satisfied.
# 2.

# %%
# Libera a memória
del modelo
del pipe
del dsa_trainer
import gc
gc.collect()
# Out:
# 60

# %%
# Carrega o modelo em fp16 e faz o merge com os pesos LoRA
base_model = AutoModelForCausalLM.from_pretrained(repositorio_hf,
                                                  low_cpu_mem_usage = True,
                                                  return_dict = True,
                                                  torch_dtype = torch.float16,
                                                  device_map = "auto")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Cria o modelo final
modelo_dsa_final = PeftModel.from_pretrained(base_model, modelo_dsa)

# %%
# Faz o merge e descarrega o modelo
modelo_dsa_final = modelo_dsa_final.merge_and_unload()

# %%
# Carrega o tokenizador
tokenizador_dsa = AutoTokenizer.from_pretrained(repositorio_hf, trust_remote_code = True)
tokenizador_dsa.pad_token = tokenizador_dsa.eos_token
tokenizador_dsa.padding_side = "right"

# %%
# Salva modelo e tokenizador
modelo_dsa_final.save_pretrained('novo_modelo-dsa-llm-projeto2')
tokenizador_dsa.save_pretrained('novo_modelo-dsa-llm-projeto2')
# Out:
# ('novo_modelo-dsa-llm-projeto2/tokenizer_config.json',
#  'novo_modelo-dsa-llm-projeto2/special_tokens_map.json',
#  'novo_modelo-dsa-llm-projeto2/tokenizer.model',
#  'novo_modelo-dsa-llm-projeto2/added_tokens.json',
#  'novo_modelo-dsa-llm-projeto2/tokenizer.json')

# %%
# Novo texto de entrada
prompt = "It's rare that a movie lives up to its hype, even rarer that the hype is transcended by the actual achievement"

# %%
# Cria o pipeline
pipe = pipeline(task = "text-generation",
                model = modelo_dsa_final,
                tokenizer = tokenizador_dsa,
                max_length = 200)

# %%
# Executa o pipeline e extrai o resultado
resultado = pipe(f"<s>[INST] {prompt} [/INST]")

# %%
print(resultado)
# Out:
# [{'generated_text': "<s>[INST] It's rare that a movie lives up to its hype, even rarer that the hype is transcended by the actual achievement [/INST]  You're absolutely right! It's not uncommon for movies to generate a lot of buzz and excitement before their release, but often the final product doesn't quite live up to the hype. Here are some reasons why this happens:\n\n1. Overhyping: Sometimes, the media and fans can get carried away with the excitement surrounding a movie, building it up to be something it's not. This can create unrealistic expectations that are difficult for the movie to meet.\n2. High expectations: When a movie is highly anticipated, the pressure to deliver can be intense. This can lead to a situation where the movie is judged more harshly than it would be if it were a less hyped film."}]

# %%
# Vamos não apenas classificar o sentimento.
# Vamos gerar texto positivo e/ou negativo a partir da avaliação (texto) inicial.
print(resultado[0]['generated_text'])
# Out:
# <s>[INST] It's rare that a movie lives up to its hype, even rarer that the hype is transcended by the actual achievement [/INST]  You're absolutely right! It's not uncommon for movies to generate a lot of buzz and excitement before their release, but often the final product doesn't quite live up to the hype. Here are some reasons why this happens:
#
# 1. Overhyping: Sometimes, the media and fans can get carried away with the excitement surrounding a movie, building it up to be something it's not. This can create unrealistic expectations that are difficult for the movie to meet.
# 2. High expectations: When a movie is highly anticipated, the pressure to deliver can be intense. This can lead to a situation where the movie is judged more harshly than it would be if it were a less hyped film.

# %%
# Libera a memória da GPU
from numba import cuda
device = cuda.get_current_device()
device.reset()

# %%
# %watermark -a "Data Science Academy"
# Out:
# Author: Data Science Academy

# %%
#%watermark -v -m

# %%
#%watermark --iversions

# %% [markdown]
# # Fim
